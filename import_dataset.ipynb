# %%
# !pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-1.0.1-py3-none-any.whl.metadata (40 kB)
# Collecting kagglesdk<1.0,>=0.1.22 (from kagglehub)
#   Downloading kagglesdk-0.1.23-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in c:\users\winni\anaconda3\lib\site-packages (from kagglehub) (24.1)
# Requirement already satisfied: pyyaml in c:\users\winni\anaconda3\lib\site-packages (from kagglehub) (6.0.1)
# Requirement already satisfied: requests in c:\users\winni\anaconda3\lib\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\winni\anaconda3\lib\site-packages (from kagglehub) (4.66.5)
# Requirement already satisfied: protobuf in c:\users\winni\anaconda3\lib\site-packages (from kagglesdk<1.0,>=0.1.22->kagglehub) (4.25.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\winni\anaconda3\lib\site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\winni\anaconda3\lib\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\winni\anaconda3\lib\site-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\winni\anaconda3\lib\site-packages (from requests->kagglehub) (2025.10.5)
# Requirement already satisfied: colorama in c:\users\winni\anaconda3\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Downloading kagglehub-1.0.1-py3-none-any.whl (70 kB)
# Downloading kagglesdk-0.1.23-py3-none-any.whl (217 kB)
# Installing collected packages: kagglesdk, kagglehub
# Successfully installed kagglehub-1.0.1 kagglesdk-0.1.23

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("andrewmvd/ocular-disease-recognition-odir5k")

print("Path to dataset files:", path)
# Out:
# Downloading to C:\Users\winni\.cache\kagglehub\datasets\andrewmvd\ocular-disease-recognition-odir5k\2.archive...
# 100%|██████████| 1.62G/1.62G [01:33<00:00, 18.6MB/s]
# Extracting files...
# Path to dataset files: C:\Users\winni\.cache\kagglehub\datasets\andrewmvd\ocular-disease-recognition-odir5k\versions\2
